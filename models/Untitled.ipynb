# %%
import yfinance as yf
import numpy as np
import tensorflow as tf

stocks = ['BNKU']

for stock in stocks:
    df = yf.download(stock, period='MAX', actions=False)
    df = df.drop(columns=['Open', 'High', 'Low', 'Close', 'Volume'])
    df = df.rename(columns={'Adj Close': 'T'})
    df = df.reset_index()

    df2 = df.copy()
    df3 = df.copy()
    df2 = df2.shift(1)
    df2['T + 1'] = df.loc[1:, 'T']
    df2 = df2.drop(0)
    df2['R'] = df2.apply(lambda row: row['T + 1'] - row['T'], axis=1)
    df2 = df2.reset_index()
    df2 = df2.drop(columns=['T', 'T + 1', 'index'])
    n = 10
    indexes = [i for i in range(n)]
    df = df2
    df2 = df2.drop(indexes)
    column = deque(df2.loc[:,'R'])
    for i in range(n):
        column.pop()
        column.appendleft(df.loc[n - i - 1, 'R'])
        df2[f'R - {i + 1}'] = column
    df_as_np = df2.to_numpy()
    time, y, x = np.split(df_as_np, [1, 2], axis=1)
    x = np.array(x)
    y = np.array(y)
    x = np.reshape(x, (x.shape[0], x.shape[1], 1))
    p_80 = int(.8 * x.shape[0])
    x = x.astype(np.float32)
    y = y.astype(np.float32)
    x_train, y_train, date_train = x[:p_80], y[:p_80], time[:p_80]
    x_test, y_test, date_test = x[p_80:], y[p_80:], time[p_80:]
    lstm = tf.keras.Sequential([
        Input((10, 1)),
        LSTM(50, return_sequences=True),
        Dropout(0.1),
        LSTM(50, return_sequences=True),
        Dropout(0.1),
        LSTM(50),
        Dense(1, activation='linear')
    ])
    lstm.compile(optimizer='adam', loss='mse')
    lstm.fit(x_train, y_train, epochs=100, shuffle=True, batch_size=10)
    lstm.save(stock + '1.keras')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Epoch 1/100
# 88/88 [==============================] - 2s 5ms/step - loss: 4.3705
# Epoch 2/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3540
# Epoch 3/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3657
# Epoch 4/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3310
# Epoch 5/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3293
# Epoch 6/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3106
# Epoch 7/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3265
# Epoch 8/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3233
# Epoch 9/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2976
# Epoch 10/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3061
# Epoch 11/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3268
# Epoch 12/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2798
# Epoch 13/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2712
# Epoch 14/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2684
# Epoch 15/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2443
# Epoch 16/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2656
# Epoch 17/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2263
# Epoch 18/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2111
# Epoch 19/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1954
# Epoch 20/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1618
# Epoch 21/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1058
# Epoch 22/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2918
# Epoch 23/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2151
# Epoch 24/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1815
# Epoch 25/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1721
# Epoch 26/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1808
# Epoch 27/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1813
# Epoch 28/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2035
# Epoch 29/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1684
# Epoch 30/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1735
# Epoch 31/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1478
# Epoch 32/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1299
# Epoch 33/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2585
# Epoch 34/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3032
# Epoch 35/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2649
# Epoch 36/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1872
# Epoch 37/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2123
# Epoch 38/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1684
# Epoch 39/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1840
# Epoch 40/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.3336
# Epoch 41/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2957
# Epoch 42/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2640
# Epoch 43/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.2277
# Epoch 44/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1824
# Epoch 45/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1717
# Epoch 46/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1060
# Epoch 47/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.1811
# Epoch 48/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.0483
# Epoch 49/100
# 88/88 [==============================] - 0s 5ms/step - loss: 4.0170
# Epoch 50/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.9784
# Epoch 51/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.8948
# Epoch 52/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.8873
# Epoch 53/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.9181
# Epoch 54/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.8912
# Epoch 55/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.7906
# Epoch 56/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.8285
# Epoch 57/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.7821
# Epoch 58/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.7745
# Epoch 59/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.7599
# Epoch 60/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.6781
# Epoch 61/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.6427
# Epoch 62/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.6212
# Epoch 63/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.5745
# Epoch 64/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.5017
# Epoch 65/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.6298
# Epoch 66/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.5016
# Epoch 67/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.5416
# Epoch 68/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.4728
# Epoch 69/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.3559
# Epoch 70/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.3949
# Epoch 71/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.3931
# Epoch 72/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.3386
# Epoch 73/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.2331
# Epoch 74/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.2447
# Epoch 75/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.2933
# Epoch 76/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.4380
# Epoch 77/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.2162
# Epoch 78/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.1870
# Epoch 79/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.1749
# Epoch 80/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.1208
# Epoch 81/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.0843
# Epoch 82/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.0416
# Epoch 83/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.0270
# Epoch 84/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.9277
# Epoch 85/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.9833
# Epoch 86/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.9299
# Epoch 87/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.9124
# Epoch 88/100
# 88/88 [==============================] - 0s 5ms/step - loss: 3.0012
# Epoch 89/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.8057
# Epoch 90/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.7712
# Epoch 91/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.7466
# Epoch 92/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.7718
# Epoch 93/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.6432
# Epoch 94/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.7482
# Epoch 95/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.6958
# Epoch 96/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.7192
# Epoch 97/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.5848
# Epoch 98/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.5765
# Epoch 99/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.6674
# Epoch 100/100
# 88/88 [==============================] - 0s 5ms/step - loss: 2.5047

# %%
lstm2 = tf.keras.models.load_model('BNKU1.keras')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 lstm2 = tf.keras.models.load_model('BNKU1.keras')
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/saving/saving_api.py:230, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     225     if kwargs:
#     226         raise ValueError(
#     227             "The following argument(s) are not supported "
#     228             f"with the native Keras format: {list(kwargs.keys())}"
#     229         )
# --> 230     return saving_lib.load_model(
#     231         filepath,
#     232         custom_objects=custom_objects,
#     233         compile=compile,
#     234         safe_mode=safe_mode,
#     235     )
#     237 # Legacy case.
#     238 return legacy_sm_saving_lib.load_model(
#     239     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     240 )
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:275, in load_model(filepath, custom_objects, compile, safe_mode)
#     272             asset_store.close()
#     274 except Exception as e:
# --> 275     raise e
#     276 else:
#     277     return model
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:240, in load_model(filepath, custom_objects, compile, safe_mode)
#     238 # Construct the model from the configuration file in the archive.
#     239 with ObjectSharingScope():
# --> 240     model = deserialize_keras_object(
#     241         config_dict, custom_objects, safe_mode=safe_mode
#     242     )
#     244 all_filenames = zf.namelist()
#     245 if _VARS_FNAME + ".h5" in all_filenames:
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:710, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     708     compile_config = config.get("compile_config", None)
#     709     if compile_config:
# --> 710         instance.compile_from_config(compile_config)
#     712 if "shared_object_id" in config:
#     713     record_object_after_deserialization(
#     714         instance, config["shared_object_id"]
#     715     )
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/engine/training.py:3582, in Model.compile_from_config(self, config)
#    3579 self.compile(**config)
#    3580 if hasattr(self, "optimizer") and self.built:
#    3581     # Create optimizer variables.
# -> 3582     self.optimizer.build(self.trainable_variables)
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/optimizers/legacy/optimizer_v2.py:997, in OptimizerV2.__getattribute__(self, name)
#     995 if name in self._hyper:
#     996     return self._get_hyper(name)
# --> 997 raise e
#
# File ~/Desktop/coding_projects/projects/stock_ai/venv/lib/python3.10/site-packages/keras/src/optimizers/legacy/optimizer_v2.py:987, in OptimizerV2.__getattribute__(self, name)
#     985 """Overridden to support hyperparameter access."""
#     986 try:
# --> 987     return super().__getattribute__(name)
#     988 except AttributeError as e:
#     989     # Needed to avoid infinite recursion with __setattr__.
#     990     if name == "_hyper":
#
# AttributeError: 'Adam' object has no attribute 'build'
